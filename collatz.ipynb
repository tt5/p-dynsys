# %% [markdown]
# A025586 largest value in the trajectory
# 1, 2, 16, 4, 16, 16, 52, 8, 52, 16, 52, 16, 40, 52, 160, 16, 52, 52
#
# A064685 length of orbit of $2n+1$
# 1, 8, 6, 17, 20, 15, 10, 18, 13, 21, 8, 16, 24, 112, 19, 107
#
# A092893 smallest starting value s.t. the sequence contains exactly $n$ tripling steps
# 1, 5, 3, 17, 11, 7, 9, 25, 33, 43, 57, 39, 105, 135, 185, 123, 169
#
# A033491 $a(n)$ is the smallest integer that takes $n$ halving and tripling steps
# 1, 2, 4, 8, 16, 5, 10, 3, 6, 12, 24, 48, 17, 34, 11, 22, 7, 14, 28, 9
