# %%
import numpy as np
from matplotlib import pyplot as plt
import math
import scipy

# %% [markdown]
# ## CA 3, Base 2

# %% [markdown]
# https://arxiv.org/abs/1301.3125

# %%
t = np.zeros((9,30), dtype='i')
t[1,-2] = 1
t[1,-3] = 1
t[1,-4] = 1
t[1,-5] = 1
t[1,-6] = 1

# %%
def processLine(t, l):
    for i in range(t.shape[1]-2,-1,-1):
        if t[l,i-1] == 2 and t[l,i] == 2 and t[l,i+1] == 2 and t[l+1,i] == 2:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 2 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 2:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 1 and t[l,i] == 2 and t[l,i+1] == 2 and t[l+1,i] == 2:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 1 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 2:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 2 and t[l,i] == 2 and t[l,i+1] == 2 and t[l+1,i] == 1:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 2 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 1:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 1 and t[l,i] == 2 and t[l,i+1] == 2 and t[l+1,i] == 1:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 1 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 1:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 2 and t[l,i] == 2 and t[l,i+1] == 1 and t[l+1,i] == 2:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 2 and t[l,i] == 1 and t[l,i+1] == 1 and t[l+1,i] == 2:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 1 and t[l,i] == 2 and t[l,i+1] == 1 and t[l+1,i] == 2:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 1 and t[l,i] == 1 and t[l,i+1] == 1 and t[l+1,i] == 2:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 2 and t[l,i] == 2 and t[l,i+1] == 1 and t[l+1,i] == 1:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 2 and t[l,i] == 1 and t[l,i+1] == 1 and t[l+1,i] == 1:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 1 and t[l,i] == 2 and t[l,i+1] == 1 and t[l+1,i] == 1:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 1 and t[l,i] == 1 and t[l,i+1] == 1 and t[l+1,i] == 1:
            t[l+1,i-1] = 1

        elif t[l,i-1] == 1 and t[l,i] == 0 and t[l,i+1] == 0 and t[l+1,i] == 0:
            t[l+1,i-1] = 0
        elif t[l,i-1] == 1 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 0:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 2 and t[l,i] == 1 and t[l,i+1] == 0 and t[l+1,i] == 0:
            t[l+1,i-1] = 0
        elif t[l,i-1] == 2 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 0:
            t[l+1,i-1] = 0
        elif t[l,i-1] == 1 and t[l,i] == 1 and t[l,i+1] == 0 and t[l+1,i] == 0:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 1 and t[l,i] == 2 and t[l,i+1] == 1 and t[l+1,i] == 0:
            t[l+1,i-1] = 0
        elif t[l,i-1] == 2 and t[l,i] == 2 and t[l,i+1] == 1 and t[l+1,i] == 0:
            t[l+1,i-1] = 1
            
        elif t[l,i-1] == 0 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 2:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 0 and t[l,i] == 1 and t[l,i+1] == 1 and t[l+1,i] == 1:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 0 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 1:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 0 and t[l,i] == 0 and t[l,i+1] == 1 and t[l+1,i] == 2:
            t[l+1,i-1] = 1
        elif t[l,i-1] == 0 and t[l,i] == 1 and t[l,i+1] == 1 and t[l+1,i] == 2:
            t[l+1,i-1] = 2
        elif t[l,i-1] == 0 and t[l,i] == 0 and t[l,i+1] == 1 and t[l+1,i] == 1:
            t[l+1,i-1] = 0

        elif t[l,i-1] == 0 and t[l,i] == 1 and t[l,i+1] == 2 and t[l+1,i] == 0:
            t[l+1,i-1] = 0
        elif t[l,i-1] == 0 and t[l,i] == 1 and t[l,i+1] == 0 and t[l+1,i] == 0:
            t[l+1,i-1] = 0
        elif t[l,i-1] == 0 and t[l,i] == 0 and t[l,i+1] == 1 and t[l+1,i] == 0:
            t[l+1,i-1] = 1

        else:
            t[l+1,i-1] = 0
            
for i in range(1,t.shape[0]-1):
    processLine(t,i)
    
plt.imshow(t, interpolation='nearest');plt.axis('off');plt.show()

# %%
plt.imshow(t, interpolation='nearest', alpha=0.2)
plt.plot([t.shape[1]-2, t.shape[1]-3, t.shape[1]-3], [1,1,2], 'o', color='black', alpha=1)
plt.plot([t.shape[1]-2, t.shape[1]-3, t.shape[1]-3], [1,1,2], '.', markersize=8, color='white', alpha=1)
plt.plot([t.shape[1]-4], [2], '.', color='black', alpha=1)
plt.plot([1,2], [0,2], linewidth=5, color='black')
plt.axis('off')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### floor

# %%
t = np.zeros((60,60), dtype='int64')
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[0,] = s
#s = [1] + [math.floor((x+1)*math.sqrt(2)) - math.floor(x*math.sqrt(2)) for x in range(t.shape[1]-2,0,-1)] + [1]
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[1,] = s

def processLine(t, l):
    for i in range(6,t.shape[1]-5):
        if t[l-1,i] != 0:
            t[l+1,i] = (math.floor((t[l,i]**2 - t[l,i-1] * t[l,i+1] + 3) // (t[l-1,i])))%5
        else:
            t[l+1,i] = 0

            
for i in range(1,t.shape[0]-1):
    processLine(t,i)

t = t%5

plt.imshow(t, interpolation='nearest');plt.axis('off');plt.show()

# %% [markdown]
# #### abs

# %%
t = np.zeros((50,100), dtype='int64')
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[0,] = s
s = [1] + [math.floor((x+1)*math.sqrt(2)) - math.floor(x*math.sqrt(2)) for x in range(t.shape[1]-2,0,-1)] + [1]
t[1,] = s

def processLine(t, l):
    for i in range(14,t.shape[1]-13):
        if t[l-1,i] != 0:
            t[l+1,i] = (abs((t[l,i]**2 - t[l,i-1] * t[l,i+1] + 2) // (t[l-1,i])))%2
        else:
            t[l+1,i] = 0

for i in range(1,t.shape[0]-1):
    processLine(t,i)

t = t%2

plt.imshow(t, interpolation='nearest');plt.axis('off');plt.show()

# %% [markdown]
# #### abs

# %%
t = np.zeros((1601,6401), dtype='int64')
t = t+1
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[0,] = s
s = [1] + [math.floor((x+1)*math.sqrt(2)) - math.floor(x*math.sqrt(2))-1 for x in range(t.shape[1]-2,0,-1)] + [1]
#s = [1] + [math.floor(math.log((3**x),2))%2 for x in range(t.shape[1]-2,0,-1)] + [1]
#print(s)
t[1,] = s

def processLine(t, l):
    for i in range(4,t.shape[1]-3):
        if t[l-1,i] != 0:
            t[l+1,i] = (abs((t[l,i]**2 - t[l,i-1] * t[l,i+1] -0) // (t[l-1,i])))
        else:
            t[l+1,i] = 1

for i in range(1,t.shape[0]-1):
    processLine(t,i)

plt.figure(figsize = (14,14))
plt.imshow(t);plt.axis('off');plt.show()

# %% [markdown]
# A056576 A022921

# %%
t = np.zeros((1601,6401), dtype='int64')
t = t+1
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[0,] = s
#s = [1] + [math.floor((x+1)*math.sqrt(2)) - math.floor(x*math.sqrt(2))-1 for x in range(t.shape[1]-2,0,-1)] + [1]
# A056576
s = [1] + [((3**x).bit_length()-1)%2 for x in range(0,t.shape[1]-2)] + [1]
#print(s)
t[1,] = s

def processLine(t, l):
    for i in range(4,t.shape[1]-3):
        if t[l-1,i] != 0:
            t[l+1,i] = (abs((t[l,i]**2 - t[l,i-1] * t[l,i+1] -0) // (t[l-1,i])))
        else:
            t[l+1,i] = 1

for i in range(1,t.shape[0]-1):
    processLine(t,i)

plt.figure(figsize = (14,14))
plt.imshow(t);plt.axis('off');plt.show()

# %%
[(3**x) >> (3**x).bit_length()-2 & 1 for x in range(1,10)]
# Out:
# [1, 0, 1, 0, 1, 0, 0, 1, 0]

# %%
t = np.zeros((503,6403), dtype='int64')
t = t+1
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[0,] = s
s = [1] + [(3**(x)) >> (3**(x)).bit_length()-2 & 1 for x in range(1,t.shape[1]-1)] + [1]
#print(s)
t[1,] = s

def processLine(t, l):
    for i in range(4,t.shape[1]-3):
        if t[l-1,i] != 0:
            t[l+1,i] = (abs((t[l,i]**2 - t[l,i-1] * t[l,i+1] -0) // (t[l-1,i])))
        else:
            t[l+1,i] = 1

for i in range(1,t.shape[0]-1):
    processLine(t,i)

pow3 = t
plt.figure(figsize = (14,14))
plt.imshow(t);plt.axis('off');plt.show()

# %%
t = np.zeros((503,6403), dtype='int64')
t = t+1
s = [1] + [1 for x in range(t.shape[1]-2,0,-1)] + [1]
t[0,] = s
s = '...'
s = [1]+[int(x) for x in list(s)[::-1]]+[1]

#print(s)
t[1,] = s

def processLine(t, l):
    for i in range(4,t.shape[1]-3):
        if t[l-1,i] != 0:
            t[l+1,i] = (abs((t[l,i]**2 - t[l,i-1] * t[l,i+1] -0) // (t[l-1,i])))
        else:
            t[l+1,i] = 1

for i in range(1,t.shape[0]-1):
    processLine(t,i)

t = t - np.roll(pow3,179, axis=1)

plt.figure(figsize = (14,14))
plt.imshow(t);plt.axis('off');plt.show()
#plt.figure(figsize = (15,15))
#plt.imshow(np.roll(pow3,180));plt.axis('off');plt.show()
