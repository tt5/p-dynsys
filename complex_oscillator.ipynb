# %% [markdown]
# # Notation

# %% [markdown]
# ## Complex Numbers

# %%
# %%latex
# $e^{ix}=\cos x+i\sin x $
# Out:
# $e^{ix}=\cos x+i\sin x $

# %%
# %%latex
# $ z\in \mathbb{C} $,
# $ z = \big| z \big| \cdot
# \big( \cos\theta + i\sin\theta \big) $
# Out:
# $ z\in \mathbb{C} $,
# $ z = \big| z \big| \cdot
# \big( \cos\theta + i\sin\theta \big) $

# %%
# %%latex
# $\big| z \big| = \sqrt{x^2 + y^2}$, $\quad i^2 = -1$
# Out:
# $\big| z \big| = \sqrt{x^2 + y^2}$, $\quad i^2 = -1$

# %%
# %%latex
# $ \cos n \theta +i \sin n \theta =
# \big( \cos \theta +i \sin \theta \big) ^n $
# Out:
# $ \cos n \theta +i \sin n \theta =
# \big( \cos \theta +i \sin \theta \big) ^n $

# %%
# %%latex
# $$\sin x=\sum_{i=0}^\infty (-1)^i\frac{x^{2i+1}}{2i+1!}$$
# $$\cos x=\sum_{i=0}^\infty (-1)^i \frac{x^{2i}}{2i!}$$
# Out:
# $$\sin x=\sum_{i=0}^\infty (-1)^i\frac{x^{2i+1}}{2i+1!}$$
# $$\cos x=\sum_{i=0}^\infty (-1)^i \frac{x^{2i}}{2i!}$$

# %% [markdown]
# ## Topology

# %% [markdown]
# **space**
# set with some structure (objects in the set are related to
# each other).

# %% [markdown]
# ## Normal Form

# %%
# %%latex
# $\frac {dz}{dt}=z\left((\lambda +i)+b|z|^{2}\right)$, $\quad z \in \mathbb{C}$
# Out:
# $\frac {dz}{dt}=z\left((\lambda +i)+b|z|^{2}\right)$, $\quad z \in \mathbb{C}$
