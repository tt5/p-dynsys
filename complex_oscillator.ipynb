# %% [markdown]
# # **Notation**

# %% [markdown]
# $\mathrm{i}^2 = -1$
#
# $n \in \mathbb{N}$
#
# $x, y, k\in \mathbb{R}$
#
# $z \in \mathbb{C}$
#
# $I$ complex identity matrix
#
# $U, V$ complex matrix
#
# $\mathrm{e}$ Euler number

# %% [markdown]
# $$\sin x=\sum_{i=0}^\infty (-1)^i\frac{x^{2i+1}}{2i+1!}$$
# $$\cos x=\sum_{i=0}^\infty (-1)^i \frac{x^{2i}}{2i!}$$

# %% [markdown]
# ## Complex Numbers

# %% [markdown]
# $\mathrm{e}^{\mathrm{i}x}=\cos x+\mathrm{i}\sin x $

# %% [markdown]
# $ z = \big| z \big| \cdot
# \big( \cos\theta + \mathrm{i}\sin\theta \big) $

# %% [markdown]
# $\big| z \big| = \sqrt{x^2 + y^2}$

# %% [markdown]
# $\cos n \theta + \mathrm{i} \sin n \theta =
# \big( \cos \theta + \mathrm{i} \sin \theta \big) ^n$

# %% [markdown]
# **unitary**: $U^\star U=UU^\star =I$

# %% [markdown]
# **root of unity**: $z^n=1$
#
# $k$-th root of unity modulo $n$ for positive
# integers $k$, $n\geqslant 2$, is a solution to the
# congruence $x^k≡1$
# If $k$ is the smallest such exponent for $x$,
# then $x$ is called a primitive $k$-th root of
# unity modulo $n$.

# %% [markdown]
# $\dot z = -\mathrm{i}\omega z$ $\quad$ harmonic oscillator, time reversable

# %% [markdown]
# ### Cauchy-Riemann Equations
#
# The Cauchy–Riemann equations on a pair of real-valued functions of two real
# variables $u(x,y)$ and $v(x,y)$ are the two equations:
#
# (1a) ${\frac {\partial u}{\partial x}}={\frac {\partial v}{\partial y}}$
# (1b) ${\frac {\partial u}{\partial y}}=-{\frac {\partial v}{\partial x}}$
#
# Typically $u$ and $v$ are taken to be the real and imaginary parts respectively of
# a complex-valued function of a single complex variable $z = x + \mathrm{i}y, f(x + \mathrm{i}y) =
# u(x,y) + \mathrm{i}v(x,y)$. Suppose that $u$ and $v$ are real-differentiable at a point in an
# open subset of $\mathbb{C}$, which can be considered as
# functions from $R^2$ to R. This implies that the partial derivatives of $u$ and $v$
# exist (although they need not be continuous) and we can approximate small
# variations of $f$ linearly. Then $f = u + \mathrm{i}v$ is complex-differentiable at that
# point if and only if the partial derivatives of $u$ and $v$ satisfy the
# Cauchy–Riemann equations (1a) and (1b) at that point. The sole existence of
# partial derivatives satisfying the Cauchy–Riemann equations is not enough to
# ensure complex differentiability at that point. It is necessary that $u$ and $v$ be
# real differentiable, which is a stronger condition than the existence of the
# partial derivatives, but it is not necessary that these partial derivatives be
# continuous.
#
# **Holomorphy** is the property of a complex function of being differentiable at
# every point of an open and connected subset of $\mathbb{C}$ (this is called a **domain** in
# $\mathbb{C}$). Consequently, we can assert that a complex function f, whose real and
# imaginary parts $u$ and $v$ are real-differentiable functions, is holomorphic if
# and only if, equations (1a) and (1b) are satisfied throughout the domain we are
# dealing with. Holomorphic functions are analytic and vice versa. This means
# that, in complex analysis, a function that is complex-differentiable in a whole
# domain (holomorphic) is the same as an analytic function. This is not true for
# real differentiable functions.

# %% [markdown]
# ## Topology

# %% [markdown]
# A **space** is a set (sometimes called a universe) with some
# added structure (object in the set are related to each other).

# %% [markdown]
# An **open set** generalizes the
# idea of an open interval in the real line.

# %% [markdown]
# Every metric space is, in a natural way, a topological space. There are, however, topological spaces that are not metric spaces.

# %% [markdown]
# A **surface** is a two-dimensional manifold.

# %% [markdown]
# ## 3D Euklidean Space

# %% [markdown]
# All three-dimensional Euclidean spaces
# are mutually isomorphic. In this sense we have "the" three-dimensional
# Euclidean space. In terms of Bourbaki, the corresponding theory is univalent

# %% [markdown]
# A vector space with a scalar product.

# %% [markdown]
# Topological notions (continuity, convergence, open sets,
# closed sets etc.) are defined naturally in every Euclidean
# space. Every Euclidean space is also a
# topological space.

# %% [markdown]
# ## Inner Product Space

# %% [markdown]
# Inner product $⟨-,-⟩:V×V→k$, sesquilinear and conjugate-symmetric.

# %% [markdown]
# ## Hilbert Space

# %% [markdown]
# Vector space with positive definite Hermitian inner product. Complete (as a topological space) with respect to the induced metric.

# %% [markdown]
# ## Normal Form of the Hopf Bifurcation

# %% [markdown]
# https://en.wikipedia.org/wiki/Hopf_bifurcation

# %% [markdown]
# A term is said to be of normal form if it does not admit any further rewrites.

# %% [markdown]
# >Normal Form: $$\dot{z}=(\lambda +\mathrm{i}\omega)z+(\alpha + \mathrm{i}\beta)|z|^{2}z$$

# %% [markdown]
# The number $α$ is called the first **Lyapunov coefficient**

# %% [markdown]
# $\omega$ und $\beta$ are optional.

# %% [markdown]
# $$r(t)=r_{0}{\sqrt {\frac {\lambda }{\left(\lambda +\alpha r_{0}^{2}\right)e^{-2\lambda t}-\alpha r_{0}^{2}}}}$$

# %% [markdown]
# If $\alpha$ is negative then there is a stable limit cycle for $\lambda >0$,
# $$z(t)=re^{\mathrm{i}\omega t}$$
# where $r={\sqrt {-\lambda /\alpha }}$ and $\omega =1+\beta r^{2}$. This is the **supercritical** regime [Verlauf]. If $\alpha$ is positive then there is an unstable limit cycle for $\lambda <0$. The *bifurcation* is said to be **subcritical**.

# %% [markdown]
# For the normal form, the *phase space* is four-dimensional: the two coordinates $x,y$ and the two velocities $\dot {x}$, $\dot {y}$.

# %% [markdown]
# The appearance or the disappearance of a periodic orbit through a local change in the stability properties of a fixed point is known as the **Hopf bifurcation**.

# %% [markdown]
# >re-write the normal form in Cartesian coordinates $z=x+\mathrm{i}y$.

# %% [markdown]
# Writing $z=re^{i\theta}$ (polar coordinates) and considering the real and imaginary parts as distinct, one obtains a pair of ordinary differential equations:
# $$\dot\theta=1+\beta r^{2} \quad
# \dot r=r\left(\lambda +\alpha r^{2}\right)$$.

# %% [markdown]
# $\alpha = 0.01$, $\quad \lambda = 0.1$, $\quad \theta = 0.1$
#
# $r_A = 3.1$, $\quad r_B = 3.2$
#
# `tspan = (0.0, 100.0)`

# %% [markdown]
# unstable limit cycle:
#
# $\alpha$, $-\lambda$
#
# 3.1 | 3.2
# - | -
# ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/pnA.png) | ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/pnB.png)

# %% [markdown]
# $\alpha$, $\lambda$
#
# 3.1 | 3.2
# - | -
# ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/ppA.png) | ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/ppB.png)

# %% [markdown]
# stable limit cycle:
#
# $-\alpha$, $\lambda$
#
# 3.1 | 3.2
# - | -
# ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/npA.png) | ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/npB.png)

# %% [markdown]
# $-\alpha$, $-\lambda$
#
# 3.1 | 3.2
# - | -
# ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/nnA.png) | ![](https://raw.githubusercontent.com/tt5/p-dynsys/refs/heads/main/code/first/nnB.png)

# %% [markdown]
# ## Jacobian

# %% [markdown]
# At each point where a function is differentiable, its Jacobian matrix can be thought of as describing the amount of "stretching", "rotating" or "transforming" that the function imposes locally near that point.

# %% [markdown]
# ## Fixed Point

# %% [markdown]
# $f(x)=x$

# %% [markdown]
# ## Differential Equation

# %% [markdown]
# A first order differential equation is said to be **linear** if it can be written
# as $y´ + p(x)y = f(x)$.  A first order differential equation that can’t be
# written like this is **nonlinear**.

# %% [markdown]
# ## Quantum Mechanics

# %% [markdown]
# The state space is a Hilbert space.

# %% [markdown]
# **Observables**: (complex) hermetian linear operators in $C^2$, also diagonalizable. Die Eigenwerte (real number) werden gemessen.

# %% [markdown]
# A **stationary state** does not change in time.

# %% [markdown]
# **degenerate state**: same Energy, different quantum states.

# %% [markdown]
# ***

# %% [markdown]
# **phase shift**: When two objects are oscillating and are not perfectly in sync, i.e., they don't reach the maximum of their oscillations at the same time, they are said to be "out of phase". The phase shift is a measure of how far apart the two oscillations are.

# %% [markdown]
# **Phase** in sinusoidal functions or in waves has two different, but closely related, meanings. One is the initial angle of a sinusoidal function at its origin and is sometimes called phase offset or phase difference. Another usage is the fraction of the wave cycle that has elapsed relative to the origin.

# %% [markdown]
# ***

# %% [markdown]
# ## Manifold

# %% [markdown]
# A **Riemann surface** is a connected one-dimensional *complex manifold*.

# %% [markdown]
# A **manifold** is a *topological space* that locally resembles Euclidean space near each point.

# %% [markdown]
# A **chart** for a topological space $M$ (also called local frame)
# is a homeomorphism $\rho$ from an open subspace $U$ of $M$ to an
# open subspace of Euclidean space.

# %% [markdown]
# An **atlas** for a *topological space* $M$ is a collection ${(U_{\alpha},\rho_\alpha)}$
# of *charts* on $M$ such that $\bigcup U_\alpha=M$. If the codomain
# of each chart is the $n$-dimensional Euclidean Space and the atlas is connected,
# then $M$ is said to be a **n-dimensional manifold**.

# %% [markdown]
# A smooth function is a function that has derivates
# of all orders everywhere in its domain. If each transition function is a smooth map, then the atlas is called
# a smooth altlas, and the manifold itself is called **smooth**.

# %% [markdown]
# All the tangent spaces can be "glued together" to form a new
# differentiable manifold of twice the dimension of the original
# manifold, called the **tangent bundle** of the manifold.

# %% [markdown]
# A **symplectic manifold** is a smooth manifold, $M$,
# equipped with a closed nondegenerate differential 2-form,
# $w$, called the symplectic form.

# %% [markdown]
# Symplectic manifolds serve as the phase spaces in the
# Hamiltonian formalism of classical mechanics, while
# four-dimensional Lorentzian manifolds model spacetime in
# general relativity.

# %% [markdown]
# ### Lie Group

# %% [markdown]
# A **Lie group** is a group that is also a *differentiable manifold*, with the
# property that the group operations are compatible with the smooth structure.

# %% [markdown]
# Euclidean space $\mathbb{R}^n$ with ordinary vector addition as the
# group operation becomes an n-dimensional noncompact abelian
# Lie group.

# %% [markdown]
# The unitary group $U(n)$ consisting of $n × n$ unitary matrices
# (with complex entries) is a compact connected Lie group
# of dimension $n^2$. Unitary matrices of determinant 1 form a
# closed connected subgroup of dimension $n^{2 − 1}$ denoted
# $SU(n)$, the special unitary group.

# %% [markdown]
# The group $\text{GL}(n, \mathbb{R})$ is a Lie group of dimension $n^2$, called the
# general linear group. It has a closed connected subgroup
# $\text{SL}(n, F)$, the special linear group, consisting of matrices
# of determinant 1 which is also a Lie group.

# %% [markdown]
# ## Tensor

# %% [markdown]
# A **Tensor** is a $n$-dimensional array of numbers.
# ($n=1$: vector; $n=2$: matrix).

# %% [markdown]
# **Tensor**: a element of the tensor product. Type $(m,n)$ tensor.
# $\underbrace{V\otimes\dots\otimes V}_m$ $\otimes$ $\underbrace{V^\star \otimes \dots \otimes V^\star}_n$

# %% [markdown]
# ## Operator

# %% [markdown]
# $\bar\alpha = \alpha$
#
# daraus folgt: real operator (self-adjoint)

# %% [markdown]
# ## Set

# %% [markdown]
# In a material set theory (also called membership-based set theory), the elements of a set exist independently of that set. The standard example is ZFC.

# %% [markdown]
# ## Eigenvalues

# %% [markdown]
# $A_{n\times n}$ matrix, $\lambda \in \mathbb{R}$ eigenvalues of $A$, $x$ eigenvector
#
# $Ax=\lambda x$ $\quad (A-\lambda I)x=0$
#
# $\det (A-\lambda I)=0$
#
# eigenvalues
# $\lambda_i=\lambda_1,...,\lambda_n$
#
# $\operatorname{trace}(A)=\sum_{i=1}^{n}\lambda_i$
#
# $\det(A)=\prod_{i=1}^{n}\lambda_i$
#
# $A^k$ has $\lambda_i^k$
#
# the eigenvalues of $A^{-1}$ are $\frac{1}{\lambda}$
