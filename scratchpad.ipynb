# %%
https://stackoverflow.com/questions/26309635/python-faster-local-maximum-in-2-d-matrix

# %%
from scipy.ndimage import maximum_filter
import numpy as np

# %%
R = np.array([[3, 3, 0, 0, 3],
       [0, 0, 2, 1, 3],
       [0, 1, 1, 1, 2],
       [3, 2, 1, 2, 0],
       [2, 2, 1, 2, 1]])

# %%
mx = maximum_filter(R, size=3)
mx == R
out = np.where(mx == R, R, 0)
out
# Out:
# array([[3, 3, 0, 0, 3],
#        [0, 0, 0, 0, 3],
#        [0, 0, 0, 0, 0],
#        [3, 0, 0, 2, 0],
#        [0, 0, 0, 2, 0]])

# %%
import numpy as np
import matplotlib.pyplot as plt

interval = (2.8, 4)  # start, end
accuracy = 0.1
reps = 6  # number of repetitions
numtoplot = 3
lims = np.zeros(reps)

fig, biax = plt.subplots()
fig.set_size_inches(16, 9)

lims[0] = np.random.rand()
for r in np.arange(interval[0], interval[1], accuracy):
    print(r)
    for i in range(reps - 1):
        lims[i + 1] = r * lims[i] * (1 - lims[i])

    print(lims)
    biax.plot([r] * numtoplot, lims[reps - numtoplot :], "b.", markersize=2)

biax.set(xlabel="r", ylabel="x", title="logistic map")
plt.show()
# Out:
# 2.8
# [0.33592501 0.62462231 0.65651398 0.63140944 0.65164836 0.63560777]
# 2.9
# [0.33592501 0.64693025 0.66239336 0.64852235 0.66102922 0.64980181]
# 3.0
# [0.33592501 0.66923819 0.66407531 0.66923788 0.66407562 0.66923757]
# 3.1
# [0.33592501 0.69154613 0.66126125 0.69438391 0.65786618 0.69774264]
# 3.2
# [0.33592501 0.71385407 0.6536526  0.72445081 0.63878987 0.73835959]
# 3.3000000000000003
# [0.33592501 0.73616201 0.64095077 0.75943851 0.60288248 0.79007014]
# 3.4000000000000004
# [0.33592501 0.75846995 0.62285717 0.79868079 0.54668527 0.84258965]
# 3.5000000000000004
# [0.33592501 0.78077789 0.59907322 0.84064574 0.46886168 0.87160642]
# 3.6000000000000005
# [0.33592501 0.80308583 0.56930033 0.88271087 0.3727166  0.84167617]
# 3.7000000000000006
# [0.33592501 0.82539377 0.53323992 0.9209119  0.26948274 0.72838863]
# 3.8000000000000007
# [0.33592501 0.84770171 0.49059339 0.94966376 0.18164951 0.56488128]
# 3.900000000000001
# ...
