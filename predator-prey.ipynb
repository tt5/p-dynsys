# %% [markdown]
# predator-prey, consumer-resource

# %% [markdown]
# https://en.wikipedia.org/wiki/Functional_response

# %% [markdown]
# https://en.wikipedia.org/wiki/Master_equation
#
# https://en.wikipedia.org/wiki/Kolmogorov_equations
#
# https://en.wikipedia.org/wiki/Gillespie_algorithm
#
# https://docs.idmod.org/projects/cms/en/latest/gibson-bruck.html

# %% [markdown]
# ## Lotka-Volterra

# %% [markdown]
# https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations

# %% [markdown]
# $$\begin{aligned}{\frac {dx}{dt}}&=\alpha x-\beta xy,\\{\frac {dy}{dt}}&=-\gamma y+\delta xy,\end{aligned}$$

# %% [markdown]
# ## Beddington-DeAngelis functional response

# %% [markdown]
# $$\dot u = r u - u^2 - \frac{\alpha u v}{\gamma + u + v}$$
#
# $$\dot v = \epsilon ( \frac{\beta u v}{\gamma + u + v} - \gamma v )$$

# %% [markdown]
# https://www.degruyterbrill.com/document/doi/10.1515/zna-2018-0449/html

# %% [markdown]
# The rate at which the consumer encounters food items per unit of food density is called the attack rate

# %% [markdown]
# The average time spent on processing a food item is called the handling time

# %% [markdown]
# The type II functional response is characterized by a decelerating intake rate, which follows from the assumption that the consumer is limited by its capacity to process food.

# %% [markdown]
# A functional response in ecology is the intake rate of a consumer as a function of food density (the amount of food available in a given ecotope). It is associated with the numerical response, which is the reproduction rate of a consumer as a function of food density. A functional response in ecology is the intake rate of a consumer as a function of food density (the amount of food available in a given ecotope). It is associated with the numerical response, which is the reproduction rate of a consumer as a function of food density.
