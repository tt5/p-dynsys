# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
t = np.arange(0.1, 110, 0.01)
gamma = np.vectorize(math.gamma)
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
log = np.vectorize(sigmoid)
cos = np.vectorize(math.cos)
#plt.plot(t, (t-20)**2 * np.exp(t-20) / gamma(t))
plt.plot(t, cos((t-8)**2 * np.exp(t-8) * gamma(t)**(-0.4-0.5*log(t-32)) + log(t-32)))

#plt.plot(gamma(t))

# %%
t = np.arange(0.1, 110, 0.01)
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
log = np.vectorize(sigmoid)
plt.plot(t, log(t-32))
