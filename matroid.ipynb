# %%
using Oscar
# Out:
#   ___   ___   ___    _    ____
#  / _ \ / __\ / __\  / \  |  _ \  | Combining and extending ANTIC, GAP,
# | |_| |\__ \| |__  / ^ \ |  ´ /  | Polymake and Singular
#  \___/ \___/ \___//_/ \_\|_|\_\  | Type "?Oscar" for more information
# o--------o-----o-----o--------o  | Documentation: https://docs.oscar-system.org
#   S Y M B O L I C   T O O L S    | Version 1.7.0

# %%
M = matroid_from_bases([[1,2],[1,3],[1,4],[2,3],[2,4]],4)
println(matroid_groundset(M))
println(bases(M))
println(nonbases(M))
println(circuits(M))
println(flats(M))
println(closure(M,[3]))
println(closure(M,[3,4]))
println(independent_sets(M))
println(tutte_polynomial(M))
println(characteristic_polynomial(M))
# Out:
# [1, 2, 3, 4]
# [[1, 2], [1, 3], [1, 4], [2, 3], [2, 4]]
# [[3, 4]]
# [[3, 4], [1, 2, 3], [1, 2, 4]]
# [Int64[], [3, 4], [2], [1], [1, 2, 3, 4]]
# [3, 4]
# [3, 4]
# [Int64[], [1], [2], [3], [4], [1, 4], [2, 4], [1, 3], [2, 3], [1, 2]]
# x^2 + x*y + x + y^2 + y
# q^2 - 3*q + 2

# %%
M = matroid_from_bases([[1,2],[1,3],[2,4],[3,4]],4)
# Out:
# Matroid of rank 2 on 4 elements
