# %% [markdown]
# two configurations are equivalent if they differ by a sequence of chip-firing moves.

# %% [markdown]
# A, B disjoint partition of vertices. Firing A and then B is the same again. Firing all vertices is the same again.

# %% [markdown]
# https://www.youtube.com/watch?v=EvSu0MQJHIA
