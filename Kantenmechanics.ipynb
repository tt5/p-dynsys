# %% [markdown]
# $$\psi = \psi_n(x) = N_nH_n(\xi)e^{-\frac{1}{2}\xi^2}$$

# %% [markdown]
# # notation

# %% [markdown]
# s-orbital, spatial orbital

# %% [markdown]
# s, l = 0
# p, l = 1
# d, l = 2

# %% [markdown]
# # notes

# %% [markdown]
# external fieldselectric
#
# electric, magnetic

# %%
Electron-electron repulsion enters the Hamiltonian.

# %% [markdown]
# $n = (n_r + 1) + l$     where $n_r$ = # radial nodes
